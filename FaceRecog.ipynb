# %%
import cv2 as cv
import os
import numpy as np

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[5], line 12
#       8 face_recognizer.read('face_trained.yml')
#      10 img = cv.imread(r"C:\Users")
# ---> 12 gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
#      13 cv.imshow("Person", gray)
#      15 # Detect the face in the image
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
# Out:
# Label = Andrew_Ng with a confidence of 57.61456030859854
# Label = Andrew_Ng with a confidence of 84.25172869850306
